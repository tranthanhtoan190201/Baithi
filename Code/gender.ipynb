# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import os
from PIL import Image
import cv2

# %%
data ='drive/MyDrive/baithi/gender_data/train'
validation ='drive/MyDrive/baithi/gender_data/validation'
test ='drive/MyDrive/baithi/gender_data/test'

# %%
IDG = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,horizontal_flip=True, fill_mode="nearest")

# %%
listdata=[]
listvalidation=[]
dict={'man1':[0],'man':[0],'woman1':[1],'woman':[1]}

# %%
def Getdata(dirdata,lstdata):
  x=0
#doc hinh anh trong tap du lieu
  for whatever in os.listdir(dirdata):
      whatever_path = os.path.join(dirdata,whatever)
      lst_filename_path=[]
      for filename in os.listdir(whatever_path):
        filename_path=os.path.join(whatever_path,filename)
        label=filename_path.split('/')[5]
        img = Image.open(filename_path)
        img=np.array(img.resize((100,100),Image.ANTIALIAS))
        lst_filename_path.append((img,dict[label]))
        x=x+1
      print(x)
      lstdata.extend(lst_filename_path)
  for i in range(3):
      np.random.shuffle(lstdata)
  return lstdata

# %%
listdata=Getdata(data,listdata)
listvalidation=Getdata(validation,listvalidation)
# Out:
# 1173
# 2351
# 3163
# 3471
# 100
# 200

# %%
x_train=np.array([x[0] for _ ,x in enumerate(listdata)])
y_train=np.array([y[1] for _ ,y in enumerate(listdata)])
x_validation=np.array([x[0] for _ ,x in enumerate(listdata)])
y_validation=np.array([y[1] for _ ,y in enumerate(listdata)])
print(x_train.shape)
# Out:
# (3471, 100, 100, 3)

# %%
yname=y_train.flatten()
class_names=['male','female']

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap='binary')
    plt.xlabel(class_names[yname[i]])
plt.show()

# %%
#x_train,x_validation,y_train,y_validation = train_test_split(x_data,y_data,test_size=0.2,random_state=100)
x_train=x_train.astype('float32')
x_validation=x_validation.astype('float32')
x_train/=255
x_validation/=255
y_train=np_utils.to_categorical(y_train,2)
y_validation= np_utils.to_categorical(y_validation,2)

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), padding="same", input_shape=(100,100,3)))
model.add(Activation("relu"))

model.add(Conv2D(64, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(128, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(128, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())
model.add(Dense(512))
model.add(Activation("relu"))
model.add(Dropout(0.2))
model.add(Dense(2,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  activation (Activation)     (None, 100, 100, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      18496
#
#  activation_1 (Activation)   (None, 100, 100, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 100, 100, 64)      36928
#
#  activation_2 (Activation)   (None, 100, 100, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 64)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       73856
#
#  activation_3 (Activation)   (None, 50, 50, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 128)       147584
#
#  activation_4 (Activation)   (None, 50, 50, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dense (Dense)               (None, 512)               40960512
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 41,239,298
# Trainable params: 41,239,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="Adam",loss='categorical_crossentropy',metrics=['accuracy'])
model_path='drive/MyDrive/baithi/model/gender.h5'
checkpointer = ModelCheckpoint(model_path, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %%
history=model.fit(IDG.flow(x_train, y_train,batch_size=100),epochs=40,verbose=1,validation_data=(x_validation,y_validation), callbacks=[callback_list])
# Out:
# Epoch 1/40
# 35/35 [==============================] - ETA: 0s - loss: 0.7246 - accuracy: 0.6033
# Epoch 1: loss improved from inf to 0.72459, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] -
40
# 35/35 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9458
# Epoch 32: loss did not improve from 0.12103
# 35/35 [==============================] - 9s 243ms/step - loss: 0.1353 - accuracy: 0.9458 - val_loss: 0.0697 - val_accuracy: 0.9741
# Epoch 33/40
# 35/35 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9481
# Epoch 33: loss did not improve from 0.12103
# 35/35 [==============================] - 10s 270ms/step - loss: 0.1298 - accuracy: 0.9481 - val_loss: 0.0599 - val_accuracy: 0.9798
# Epoch 34/40
# 35/35 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9585
# Epoch 34: loss improved from 0.12103 to 0.10943, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] - 12s 335ms/step - loss: 0.1094 - accuracy: 0.9585 - val_loss: 0.0605 - val_accuracy: 0.9775
# Epoch 35/40
# 35/35 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9582
# Epoch 35: loss did not improve from 0.10943
# 35/35 [==============================] - 9s 244ms/step - loss: 0.1159 - accuracy: 0.9582 - val_loss: 0.0614 - val_accuracy: 0.9761
# Epoch 36/40
# 35/35 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9620
# Epoch 36: loss improved from 0.10943 to 0.09935, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] - 10s 297ms/step - loss: 0.0993 - accuracy: 0.9620 - val_loss: 0.0591 - val_accuracy: 0.9781
# Epoch 37/40
# 35/35 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9620
# Epoch 37: loss improved from 0.09935 to 0.09888, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] - 10s 279ms/step - loss: 0.0989 - accuracy: 0.9620 - val_loss: 0.0525 - val_accuracy: 0.9813
# Epoch 38/40
# 35/35 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9591
# Epoch 38: loss did not improve from 0.09888
# 35/35 [==============================] - 9s 245ms/step - loss: 0.0998 - accuracy: 0.9591 - val_loss: 0.0562 - val_accuracy: 0.9810
# Epoch 39/40
# 35/35 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9628
# Epoch 39: loss improved from 0.09888 to 0.09481, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] - 11s 303ms/step - loss: 0.0948 - accuracy: 0.9628 - val_loss: 0.0577 - val_accuracy: 0.9770
# Epoch 40/40
# 35/35 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9643
# Epoch 40: loss improved from 0.09481 to 0.09250, saving model to drive/MyDrive/baithi/model/gender.h5
# 35/35 [==============================] - 10s 279ms/step - loss: 0.0925 - accuracy: 0.9643 - val_loss: 0.0447 - val_accuracy: 0.9844

# %%
model_gender=load_model('drive/MyDrive/baithi/model/gender.h5')

# %%
listtest=[]
listtest=Getdata(test,listtest)
x_test=np.array([x[0] for _ ,x in enumerate(listtest)])
print(x_test.shape)
# Out:
# 6
# 12
# (12, 100, 100, 3)

# %%
x_test[0].shape
# Out:
# (100, 100, 3)

# %%
plt.figure(figsize=(20, 20))
for i in range(12):
    plt.subplot(4, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[i], cmap='binary')
    plt.title("gioi tinh: " + str(class_names[np.argmax(model_gender.predict(x_test[i].reshape((-1,100,100,3))))]))
plt.show()

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 5.1 MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
#khai báo thư viện
import cv2
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
image_path='drive/MyDrive/baithi/gender_data/test nhieu mat/em.jpg'

# %%
class_names=['male','female']
img=plt.imread(image_path)
detector=MTCNN() ## THU VIEN DA TRAIN SAN
faces=detector.detect_faces(img)
i=0
for face in faces:
  i = i+1
  x,y,w,h=face['box']
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),3)
  img_cat=img[y:y+h,x:x+w]
  img_cat=np.resize(img_cat, (100,100,3))
  img_cat=img_cat.astype('float32')
  img_cat/=255
  output_gender=class_names[np.argmax(model_gender.predict(img_cat.reshape(-1,100,100,3)))]
  output_str = str(i) + ": "+  output_gender
  print(output_str)
  col = (0,255,0)
  cv2.putText(img, str(i),(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,col,2)
plt.imshow(img)
# Out:
# 1: male
